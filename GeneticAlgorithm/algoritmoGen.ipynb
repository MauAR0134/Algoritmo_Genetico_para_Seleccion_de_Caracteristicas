# %% [markdown]
# ## Ejecución del Algoritmo Genetico

# %%
# Establecer el autoreload

# %load_ext autoreload
# %autoreload 2

# %%
# Importar la paqueteria

import numpy as np
import pandas as pd
import random
from tqdm import trange

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# %%
import algoritmo_genetico as ag

# %%
# Cargar los datos

data = pd.read_csv("df_expresion.csv")
target = pd.read_csv("target.csv")

data2 = pd.read_csv("df_expresionTax2.csv")
target2 = pd.read_csv("targetTax2.csv")

nombres_columnas = data.columns.to_list()
nombres_columnas2=data2.columns.to_list()

# %%
# print("Data1:",data.head(),"Target1:",target.head())
# print("Data2:",data2.head(),"Target1:",target2.head())

# %%
# ------------------------------
# Definir genes disponibles
# ------------------------------
LEGO = list(range(len(nombres_columnas)))  # ajusta según tu dataset

# ------------------------------
# Ejecutar el Algoritmo Genético
# ------------------------------

df_historial, mejoresXgen, mejor_global,best_fitness, parametros = ag.algoritmo_genetico(
    fitness_func=ag.fitness,
    modo=1,
    LEGO=LEGO,
    IND_LEN=5,
    POP_SIZE=5,
    POP_NUM=1,
    GENS=10,
    MUT_RATE=0.1,
    MUT_NULL_RATE=0.1,
    ELITISM=0.1,
    df_expresion=data,
    target=target,
    nombres_columnas=nombres_columnas, 
    modelo="rf",
    metric="accuracy",
    random_state=42
)

# ------------------------------
# Visualización de resultados
# ------------------------------
ag.plot_ag_results(df_historial, mejor_global,best_fitness, parametros,nombres_columnas=nombres_columnas)
# Out:
# Evolución AG: 100%|██████████| 10/10 [00:35<00:00,  3.60s/it]

# %%
ag.info_individuo(mejor_global, data)
