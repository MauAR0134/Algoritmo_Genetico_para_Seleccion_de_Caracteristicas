# %%
import numpy as np
import pandas as pd
import polars as ps
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scanpy as sc
from scipy.sparse import csr_matrix

# %%
# Cargar el archivo
adata = sc.read_h5ad("humanM1.h5ad")

# %%
adata.obs['subclass_label']
# Out:
# sample_name
# AAACCCAAGGATTTCC-LKTX_190129_01_A01        Sst
# AAACCCAAGTATGGCG-LKTX_190129_01_A01    L5/6 NP
# AAACCCACAAAGTGTA-LKTX_190129_01_A01      L5 IT
# AAACCCACACTACTTT-LKTX_190129_01_A01    L2/3 IT
# AAACCCACAGTGAGCA-LKTX_190129_01_A01      Oligo
#                                         ...
# TTTGTTGAGATGGCGT-LKTX_190130_01_H01      Oligo
# TTTGTTGCACAGCCAC-LKTX_190130_01_H01      L5 IT
# TTTGTTGCAGAGACTG-LKTX_190130_01_H01    L2/3 IT
# TTTGTTGCATAATGAG-LKTX_190130_01_H01      Oligo
# TTTGTTGTCTACTCAT-LKTX_190130_01_H01      Pvalb
# Name: subclass_label, Length: 76533, dtype: category
# Categories (20, object): ['Astro', 'Endo', 'L2/3 IT', 'L5 ET', ..., 'Sst', 'Sst Chodl', 'VLMC', 'Vip']

# %%
sc.pl.umap(adata, color = 'class_label')
sc.pl.umap(adata, color = 'subclass_label')

# %%
sc.pl.tsne(adata, color='class_label')
sc.pl.tsne(adata, color='subclass_label')
